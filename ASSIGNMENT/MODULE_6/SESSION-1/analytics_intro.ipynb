# %%
name = "Mahek"
Favorite_app = "Reddit"

print("name:", name)
print("Favorite App:", Favorite_app)
# Out:
# name: Mahek
# Favorite App: Reddit

# %%
import datetime

print("Current Year:", datetime.datetime.now().year)
# Out:
# Current Year: 2026
